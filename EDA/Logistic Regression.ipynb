# %% [markdown]
# Exploratory Data Analysis by applying Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %pip install seaborn
